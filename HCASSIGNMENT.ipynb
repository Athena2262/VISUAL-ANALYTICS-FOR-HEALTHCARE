# %% [markdown]
# <a href="https://colab.research.google.com/github/Athena2262/VISUAL-ANALYTICS-FOR-HEALTHCARE/blob/main/HCASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
df = pd.read_csv('/content/sleep.csv')
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
mean = df['Sleep Duration'].mean()
var = df['Sleep Duration'].var()
std = df['Sleep Duration'].std()
print (f"Mean {mean}\nVariance {var}\nStandard Deviation = {std}")
# Out:
# Mean 7.132085561497325
# Variance 0.6330696334102738
# Standard Deviation = 0.7956567308898189

# %%
mean = df['Physical Activity Level'].mean()
var = df['Physical Activity Level'].var()
std = df['Physical Activity Level'].std()
print (f"Mean {mean}\nVariance {var}\nStandard Deviation = {std}")
# Out:
# Mean 59.17112299465241
# Variance 433.92238104113204
# Standard Deviation = 20.83080365807167

# %%
plt.figure(figsize=(10,2))
plt.boxplot(df['Stress Level'], vert=False, showmeans=True)
plt.grid(color='blue', linestyle='dotted')
plt.show()

# %%
sns.lineplot(x='Stress Level', y='Sleep Duration', data=df)
plt.show()

# %%
sns.scatterplot(x='Sleep Duration', y='Physical Activity Level', data=df,
               hue='Heart Rate')
plt.show()

# %%
plt.figure(figsize=(10,2))
plt.boxplot(df['Heart Rate'], vert=False, showmeans=True)
plt.grid(color='blue', linestyle='dotted')
plt.show()

# %%
fig = px.scatter(df, x='Stress Level', y='Blood Pressure', title='Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.barplot(x='Sleep Duration', y='Physical Activity Level', data=df,
               hue='Heart Rate')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# reading the database


# Scatter plot with day against tip
plt.plot(df['Sleep Duration'])
plt.plot(df['Physical Activity Level'])



# Setting the X and Y labels
plt.xlabel('Sleep Duration')
plt.ylabel('Physical Activity Level')

plt.show()
